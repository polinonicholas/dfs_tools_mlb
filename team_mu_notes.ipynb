# %%
from dfs_tools_mlb.compile import teams
import pandas
from dfs_tools_mlb import settings
pandas.set_option("display.max_columns", None)

# %%
swap = False
t = teams.orioles
o = teams.red_sox
if not swap:
    teams.Team.team_notes(t, o, extend=True)
else:
    teams.Team.team_notes(o, t, extend=True)
# Out:
# Report for orioles vs. red sox:
#               name  fd_wps_b_vr  fd_wps_b_vl  batters_faced_vl  pitches_start  \
# 7  Kutter Crawford     0.628514     0.403702             114.0      83.444444
#
#    mlb_id
# 7  676710
# {'avg_home_score': 6.0, 'avg_away_score': 4.75, 'avg_home_hits': 9.5, 'avg_away_hits': 7.5, 'sample_home': 6, 'sample_away': 4, 'avg_hits': 8.5, 'avg_score': 5.375, 'home_fd': 68.7, 'away_fd': 54.325, 'total_fd': 61.5125, 'pitcher': 'Kutter Crawford'}
#                 name  fd_wpa_pa_vr   pa_vr  fd_hr_weight_vr bat_side
# 0     Cedric Mullins      0.027957  1083.0         0.758756        L
# 1    Adley Rutschman     -0.100095   413.0         0.752847        L
# 2  Anthony Santander      0.284255   925.0         0.912370        L
# 3   Ryan Mountcastle      0.577000  1011.0         0.922629        R
# 4       Kyle Stowers      0.355651    14.0         0.682854        L
# 5        Austin Hays      0.401959   919.0         0.700828        R
# ...

# %%
t.lineup_df()[["name", "points", "exp_ps_sp_pa", "sp_split","mlb_id", "team", "is_platoon",
                       "venue_points",  "total_pitches", "bat_side", "order", "pitches_pa_vr", "fd_wpa_pa_vr"]].describe()
# Out:
#           points  exp_ps_sp_pa  sp_split         mlb_id  venue_points  \
# count   9.000000      9.000000  9.000000       9.000000      9.000000
# mean   14.649779      3.082456  2.618780  641448.888889      0.801427
# std     3.070915      0.477919  0.278036   30220.945350      0.117335
# min    11.743189      2.507924  2.284998  596059.000000      0.711901
# 25%    12.314026      2.620624  2.519211  622761.000000      0.737596
# 50%    14.120759      3.254710  2.598112  656775.000000      0.747730
# 75%    15.264766      3.417248  2.610073  668939.000000      0.782415
# max    19.872309      3.698166  3.171909  669720.000000      1.018581
#
#        total_pitches     order  pitches_pa_vr  fd_wpa_pa_vr
# count       9.000000  9.000000       9.000000      9.000000
# mean     4006.111111  5.000000       3.842187      0.365368
# std      1899.235336  2.738613       0.188033      0.265512
# min        54.000000  1.000000       3.565832     -0.100095
# ...

# %%
t.lineup_df()[["name", "points", "exp_ps_sp_pa", "sp_split","mlb_id", "team", "is_platoon",
                       "venue_points",  "total_pitches", "bat_side", "order", "pitches_pa_vr", "fd_wpa_pa_vr"]]
# Out:
#                 name     points  exp_ps_sp_pa  sp_split  mlb_id     team  \
# 0     Cedric Mullins  19.348742      3.574736  2.925049  656775  orioles
# 1    Adley Rutschman  19.872309      3.698166  3.171909  668939  orioles
# 2  Anthony Santander  15.264766      3.417248  2.610073  623993  orioles
# 3   Ryan Mountcastle  12.334201      2.648689  2.599110  663624  orioles
# 4       Kyle Stowers  14.682980      3.411268  2.598112  669065  orioles
# 5        Austin Hays  12.314026      2.620624  2.542980  669720  orioles
# 6       Rougned Odor  14.120759      3.254710  2.284998  596059  orioles
# 7        Ramon Urias  12.167037      2.608739  2.519211  602104  orioles
# 8        Jorge Mateo  11.743189      2.507924  2.317581  622761  orioles
#
#   is_platoon  venue_points  total_pitches bat_side  order  pitches_pa_vr  \
# 0        NaN      0.991744         6162.0        L      1       3.768236
# 1        NaN      1.018581         2410.0        L      2       4.217918
# ...

# %%
o.lineup_df()[["name", "points", "exp_ps_sp_pa", "sp_split","mlb_id", "team", "is_platoon",
                       "venue_points",  "total_pitches", "bat_side", "order", "pitches_pa_vr", "fd_wpa_pa_vr"]].describe()
# Out:
#           points  exp_ps_sp_pa  sp_split         mlb_id  venue_points  \
# count   9.000000      9.000000  9.000000       9.000000      9.000000
# mean   14.170262      3.166286  2.544303  596836.666667      0.799296
# std     1.516293      0.327282  0.433202   50278.083943      0.103622
# min    12.162942      2.830906  2.057202  502054.000000      0.623427
# 25%    13.202856      2.944144  2.302247  571771.000000      0.742891
# 50%    14.058285      3.097703  2.469378  608701.000000      0.800390
# 75%    14.493659      3.329696  2.623579  624512.000000      0.847547
# max    16.535472      3.872742  3.555468  657077.000000      1.000403
#
#        total_pitches     order  pitches_pa_vr  fd_wpa_pa_vr
# count       9.000000  9.000000       9.000000      9.000000
# mean     4299.444444  5.000000       3.858330      0.293008
# std      1892.035353  2.738613       0.240461      0.208513
# min      1563.000000  1.000000       3.583102     -0.015894
# ...

# %%
o.lineup_df()[["name", "points", "exp_ps_sp_pa", "sp_split","mlb_id", "team", "is_platoon",
                       "venue_points",  "total_pitches", "bat_side", "order", "pitches_pa_vr", "fd_wpa_pa_vr"]]
# Out:
#                 name     points  exp_ps_sp_pa  sp_split  mlb_id  team  \
# 0        Jake Fraley  19.475085      3.939584  3.105780  641584  reds
# 1     Jonathan India  12.688205      3.182462  2.848995  663697  reds
# 2        Kyle Farmer  11.544248      2.859757  2.203584  571657  reds
# 3     Mike Moustakas  13.761353      3.581671  2.389953  519058  reds
# 4        Nick Senzel  10.932861      2.776440  2.036950  669222  reds
# 5  Albert Almora Jr.  10.944739      2.754012  1.992094  546991  reds
# 6          TJ Friedl  12.953681      3.352931  1.932473  670770  reds
# 7       Jose Barrero  10.401919      2.552054  1.588178  676480  reds
# 8  Michael Papierski  12.056406      3.169829  1.566268  657709  reds
#
#   is_platoon  venue_points  total_pitches bat_side  order  pitches_pa_vr  \
# 0        NaN      0.406534         2010.0        L      1       4.366569
# 1        NaN     -0.936112         4668.0        R      2       4.091130
# ...
